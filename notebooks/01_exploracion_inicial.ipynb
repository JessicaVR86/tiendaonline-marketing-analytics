# %%
print("Spark version:", spark.version)
df_prueba = spark.range(5)
df_prueba.show()

# %%
df =spark.table("workspace.default.sesiones_web")
df.printSchema()
df.show(5)
print(f"\nTotal de filas: {df.count()}")
